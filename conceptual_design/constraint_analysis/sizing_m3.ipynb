# %% [markdown]
# # Sizing M3
#
# Edgar Hernandez

# %%
from sizing import aircraft
import numpy as np


conditions = { 'altitude asl':397,'cruise altitude agl':10}
aircraft_design_parameters = {'aspect ratio' : 4,'wing span':1.5,'CLmax':0.85,'CDmin_no_fuselage':0.04,'fineness ratio':6,'m2 bank angle':np.pi/3, 'm3 bank angle': np.pi/4}
aircraft_design_parameters['conditions'] = conditions
mission_parameters = {'cargo':3,'ducks':15,'mission two cruise speed': 18,'banner length':5,'mission three cruise speed':15,'banner aspect ratio':5}
course_parameters = {'ground run': 20,'time limit': 300,'length of straights': 304.8 }
initial_guess = {'motor mass': 0.1,'m2 battery mass': 0.8,'m3 battery mass':0.5}

my_plane=aircraft(aircraft_design_parameters, mission_parameters, course_parameters, initial_guess)

my_plane.size_aircraft_all_missions(show_summary=True, debug_text=True)

# print(my_plane.eff_system_cruise)
# print(my_plane.drag_m3_cruise)
# print(my_plane.drag_m3_turn)
# Out:
# $$$$$$$$$$ Debugging $$$$$$$$$$
#
# === mission two stuffs ===
# Drag buildup...
# > cd_fus_tof: 0.004570762855761411, cd_fus_cruise: 0.004280020772716971
# > cd_tof: 0.09077037409410273, cd_cruise: 0.05397023909365854
# > D_tof: 4.461867086847674, D_cruise: 5.792675833254513, D_turn: 8.912856200953152
# Power buildup...
# > P_motor_tof: 316.19482029335467, P_motor_cruise: 260.67041249645314, P_motor_turn: 401.0785290428919
# climb rate: 3.808777944989546
# Course params...
# > t_tof: 3.2837015354163754, t_climb: 2.6255140479257966, t_cruise: 493.8307244805588
#
# === mission three stuff ===
# Drag buildup...
# > cd_fus_tof: 0.004586395175842483, cd_fus_cruise: 0.004408735276458788
# > cd_tof: 0.2907860064141838, cd_cruise: 0.3130332264201943
# > cd_banner_tof: 0.2, cd_banner_cruise: 0.25
# > D_tof: 13.761283490703093, D_cruise: 22.38438248307956, D_turn: 24.72022953076756
# Power buildup...
# > P_motor_tof: 380.60571798995454, P_motor_cruise: 839.4143431154835, P_motor_turn: 927.0086074037836
# > climb rate: 10.331980060792036
# Course params...
# > t_tof: 3.346626214255279, t_climb: 0.9678686893665388, t_cruise: 491.2549120934866
#
# === Extras ===
# > Vol_batt: 0.00039968895420916474 m^2, Vol_motor: 2.0107507990358026e-05 m^2
#
#  test: P_m3_level_batt; 1090.8568461539744, P_m3_turn_batt: 1204.6895482830193, P_m3_turn_avail: 370.80344296151344
#
#
#
#
# ====== Parameters =======
# wingspan: 1.5 m, chord: 0.375 m
# area: 0.5625 m^2, aspect ratio: 4.0
# ducks: 15, pucks: 3, m2 lap: 6.0
# banner length: 5, m3 laps: 5.0
# ====== Mission two performance =======
#  Mission two score: 1.1686470904352797, mass: 3.5199545169194337 kg, net_income: 387.8883080011431
# total energy needed for m2: 39.79552624032404 W*hr
# wing loading: 61.38800677507493 N/m^2, power loading: 15.094360920343494 W/N
# stall speed: 11.073977330593607 m/s, lift off speed: 12.181375063652968 m/s, cruise speed: 18 m/s
# ======= Mission three performance =======
#  Mission three score: 2.6367591935324857, mass: 3.3888315887257896 kg, m3_cost: 1273.518387064971
# total energy needed for m3: 117.78681136504437 W*hr
# wing loading: 59.101222907377775 N/m^2, power loading: 36.2373264494896 W/N
# stall speed: 10.86575973400971 m/s, lift off speed: 11.952335707410683 m/s, cruise speed: 15 m/s
# ======= Overall performance =======
# motor power: 927.0086074037836 W, battery power: 1204.6895482830193 W
# total mission score: 5.3768348553963365, gm: 0.5714285714285714
#  load_factor_m2: 1.9999999999999996, load_factor_m3: 1.414213562373095
