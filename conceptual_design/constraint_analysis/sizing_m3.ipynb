# %% [markdown]
# # Sizing M3
#
# Edgar Hernandez

# %%
from sizing import aircraft
import numpy as np

conditions = { 'altitude asl':397,'cruise altitude agl':10}
aircraft_design_parameters = {'aspect ratio' : 4,'wing span':1.5,'CLmax':0.85,'CDmin_no_fuselage':0.04,'fineness ratio':6,'turning bank angle':np.pi/6}
aircraft_design_parameters['conditions'] = conditions
mission_parameters = {'cargo':3,'ducks':15,'mission two cruise speed': 18,'banner length':5,'mission three cruise speed':15,'banner aspect ratio':5}
course_parameters = {'ground run': 20,'time limit': 300,'length of straights': 304.8 }
initial_guess = {'motor mass': 0.1,'m2 battery mass': 0.8,'m3 battery mass':0.5}

my_plane=aircraft(aircraft_design_parameters, mission_parameters, course_parameters, initial_guess)

my_plane.size_aircraft_all_missions(show_summary=True, debug_text=True)

# print(my_plane.eff_system_cruise)
# print(my_plane.drag_m3_cruise)
# print(my_plane.drag_m3_turn)
# Out:
# $$$$$$$$$$ Debugging $$$$$$$$$$
#
# === mission two stuffs ===
# Drag buildup...
# > cd_fus_tof: 0.004616470165379354, cd_fus_cruise: 0.0043286712771005535
# > cd_tof: 0.09081608140372065, cd_cruise: 0.05428680814440877
# > D_tof: 4.525405778739947, D_cruise: 5.82665348317107, D_turn: 6.182925506074861
# Power buildup...
# > P_motor_tof: 326.3337610600889, P_motor_cruise: 262.19940674269816, P_motor_turn: 278.2316477733687
# climb rate: 2.884980492732489
# Course params...
# > t_tof: 3.261388561805629, t_climb: 3.466227943374608, t_cruise: 451.08516712717085
#
# === mission three stuff ===
# Drag buildup...
# > cd_fus_tof: 0.004567276516372933, cd_fus_cruise: 0.00445857556070187
# > cd_tof: 0.8907668877547142, cd_cruise: 0.570769714937143
# > cd_banner_tof: 0.8, cd_banner_cruise: 0.5
# > D_tof: 50.104545049335954, D_cruise: 41.31840827502402, D_turn: 43.19623336136991
# Power buildup...
# > P_motor_tof: 903.3628623168473, P_motor_cruise: 1549.4403103134007, P_motor_turn: 1619.8587510513717
# > climb rate: 15.502429551490312
# Course params...
# > t_tof: 3.069682078821467, t_climb: 0.6450601801985715, t_cruise: 460.7319600410138
#
# === Extras ===
# > Vol_batt: 0.0007179078303394827 m^2, Vol_motor: 3.511178007054823e-05 m^2
#
#  test: P_m3_level_batt; 2013.5676547282656, P_m3_turn_batt: 2105.0795985073055, P_m3_turn_avail: 647.9435004205487
#
#
#
#
# ====== Parameters =======
# wingspan: 1.5 m, chord: 0.375 m
# area: 0.5625 m^2, aspect ratio: 4.0
# ducks: 15, pucks: 3, m2 lap: 4.0
# banner length: 5, m3 laps: 4.0
# ====== Mission two performance =======
#  Mission two score: 1.0859531652327954, mass: 3.5682832093781482 kg, net_income: 300.8360783147838
# total energy needed for m2: 37.40842732469808 W*hr
# wing loading: 62.23085917155491 N/m^2, power loading: 12.115045746697024 W/N
# stall speed: 11.149740570471636 m/s, lift off speed: 12.264714627518801 m/s, cruise speed: 18 m/s
# ======= Mission three performance =======
#  Mission three score: 2.188669390676292, mass: 4.02789004367043 kg, m3_cost: 1018.8147096519767
# total energy needed for m3: 211.7891802403465 W*hr
# wing loading: 70.2464023616123 N/m^2, power loading: 53.27480988157696 W/N
# stall speed: 11.846059438701657 m/s, lift off speed: 13.030665382571824 m/s, cruise speed: 15 m/s
# ======= Overall performance =======
# motor power: 1619.8587510513717 W, battery power: 2105.0795985073055 W
# total mission score: 5.274622555909088, gm: 1, load_factor: 1.1547005383792515
